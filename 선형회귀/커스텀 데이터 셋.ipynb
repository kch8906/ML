# %%
import torch
import torch.nn.functional as F

# %%
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

# %%
# Dataset 상속
class CustomDataset(Dataset): 
    def __init__(self):
        self.x_data = [[73, 80, 75],
                       [93, 88, 93],
                       [89, 91, 90],
                       [96, 98, 100],
                       [73, 66, 70]]
        self.y_data = [[152], [185], [180], [196], [142]]
        
    def __len__(self): 
        return len(self.x_data)
        
    def __getitem__(self, idx): 
        x = torch.FloatTensor(self.x_data[idx])
        y = torch.FloatTensor(self.y_data[idx])
        return x, y

# %%
dataset = CustomDataset()
dataloader = DataLoader(dataset, batch_size=2, shuffle=True)

# %%
model = torch.nn.Linear(3,1)
optimizer = torch.optim.SGD(model.parameters(), lr=1e-5)

# %%
nb_epochs = 50
for epoch in range(nb_epochs + 1):
    for batch_idx, samples in enumerate(dataloader):
        x_train, y_train = samples
    
        prediction = model(x_train)

   
        cost = F.mse_loss(prediction, y_train)

       
        optimizer.zero_grad()
        cost.backward()
        optimizer.step()

        print('Epoch {:4d}/{} Batch {}/{} Cost: {:.6f}'.format(
            epoch, nb_epochs, batch_idx+1, len(dataloader),
            cost.item()
            ))
# Out:
# Epoch    0/50 Batch 1/3 Cost: 52083.093750
# Epoch    0/50 Batch 2/3 Cost: 19032.929688
# Epoch    0/50 Batch 3/3 Cost: 3571.490479
# Epoch    1/50 Batch 1/3 Cost: 1379.447876
# Epoch    1/50 Batch 2/3 Cost: 928.482300
# Epoch    1/50 Batch 3/3 Cost: 259.487396
# Epoch    2/50 Batch 1/3 Cost: 41.691711
# Epoch    2/50 Batch 2/3 Cost: 13.945877
# Epoch    2/50 Batch 3/3 Cost: 8.327860
# Epoch    3/50 Batch 1/3 Cost: 0.720250
# Epoch    3/50 Batch 2/3 Cost: 1.558072
# Epoch    3/50 Batch 3/3 Cost: 0.044103
# Epoch    4/50 Batch 1/3 Cost: 0.919312
# Epoch    4/50 Batch 2/3 Cost: 0.448029
# Epoch    4/50 Batch 3/3 Cost: 0.118489
# Epoch    5/50 Batch 1/3 Cost: 0.256602
# Epoch    5/50 Batch 2/3 Cost: 0.918993
# Epoch    5/50 Batch 3/3 Cost: 0.083390
# Epoch    6/50 Batch 1/3 Cost: 0.144758
# Epoch    6/50 Batch 2/3 Cost: 0.559046
# Epoch    6/50 Batch 3/3 Cost: 1.067666
# Epoch    7/50 Batch 1/3 Cost: 0.163848
# Epoch    7/50 Batch 2/3 Cost: 0.805276
# Epoch    7/50 Batch 3/3 Cost: 0.135466
# Epoch    8/50 Batch 1/3 Cost: 0.482410
# Epoch    8/50 Batch 2/3 Cost: 0.618876
# Epoch    8/50 Batch 3/3 Cost: 0.129161
# Epoch    9/50 Batch 1/3 Cost: 0.177992
# Epoch    9/50 Batch 2/3 Cost: 0.902783
# Epoch    9/50 Batch 3/3 Cost: 0.222626
# Epoch   10/50 Batch 1/3 Cost: 0.120039
# Epoch   10/50 Batch 2/3 Cost: 0.587952
# Epoch   10/50 Batch 3/3 Cost: 0.739680
# Epoch   11/50 Batch 1/3 Cost: 0.172628
# Epoch   11/50 Batch 2/3 Cost: 0.852908
# Epoch   11/50 Batch 3/3 Cost: 0.043904
# Epoch   12/50 Batch 1/3 Cost: 0.073815
# Epoch   12/50 Batch 2/3 Cost: 0.794220
# Epoch   12/50 Batch 3/3 Cost: 0.118426
# Epoch   13/50 Batch 1/3 Cost: 0.387489
# Epoch   13/50 Batch 2/3 Cost: 0.061140
# Epoch   13/50 Batch 3/3 Cost: 1.223343
# Epoch   14/50 Batch 1/3 Cost: 0.525353
# Epoch   14/50 Batch 2/3 Cost: 0.585966
# Epoch   14/50 Batch 3/3 Cost: 0.002136
# Epoch   15/50 Batch 1/3 Cost: 0.493307
# Epoch   15/50 Batch 2/3 Cost: 0.824664
# Epoch   15/50 Batch 3/3 Cost: 0.054817
# Epoch   16/50 Batch 1/3 Cost: 0.070995
# Epoch   16/50 Batch 2/3 Cost: 0.661309
# Epoch   16/50 Batch 3/3 Cost: 0.934018
# Epoch   17/50 Batch 1/3 Cost: 0.954757
# Epoch   17/50 Batch 2/3 Cost: 0.100524
# Epoch   17/50 Batch 3/3 Cost: 0.482208
# Epoch   18/50 Batch 1/3 Cost: 0.043511
# Epoch   18/50 Batch 2/3 Cost: 1.169052
# Epoch   18/50 Batch 3/3 Cost: 0.127739
# Epoch   19/50 Batch 1/3 Cost: 0.378966
# Epoch   19/50 Batch 2/3 Cost: 0.060501
# Epoch   19/50 Batch 3/3 Cost: 1.227465
# Epoch   20/50 Batch 1/3 Cost: 0.295532
# Epoch   20/50 Batch 2/3 Cost: 0.457648
# Epoch   20/50 Batch 3/3 Cost: 1.219195
# Epoch   21/50 Batch 1/3 Cost: 0.802228
# Epoch   21/50 Batch 2/3 Cost: 0.457633
# Epoch   21/50 Batch 3/3 Cost: 0.263718
# Epoch   22/50 Batch 1/3 Cost: 0.240254
# Epoch   22/50 Batch 2/3 Cost: 0.711267
# Epoch   22/50 Batch 3/3 Cost: 0.104278
# Epoch   23/50 Batch 1/3 Cost: 0.153573
# Epoch   23/50 Batch 2/3 Cost: 0.306071
# Epoch   23/50 Batch 3/3 Cost: 1.301757
# Epoch   24/50 Batch 1/3 Cost: 0.859715
# Epoch   24/50 Batch 2/3 Cost: 0.020800
# Epoch   24/50 Batch 3/3 Cost: 0.333876
# Epoch   25/50 Batch 1/3 Cost: 0.120199
# Epoch   25/50 Batch 2/3 Cost: 0.222354
# Epoch   25/50 Batch 3/3 Cost: 1.415924
# Epoch   26/50 Batch 1/3 Cost: 0.236111
# Epoch   26/50 Batch 2/3 Cost: 0.782384
# Epoch   26/50 Batch 3/3 Cost: 0.080914
# Epoch   27/50 Batch 1/3 Cost: 0.413561
# Epoch   27/50 Batch 2/3 Cost: 0.678837
# Epoch   27/50 Batch 3/3 Cost: 0.341929
# Epoch   28/50 Batch 1/3 Cost: 0.120417
# Epoch   28/50 Batch 2/3 Cost: 0.792264
# Epoch   28/50 Batch 3/3 Cost: 0.015809
# Epoch   29/50 Batch 1/3 Cost: 0.380516
# Epoch   29/50 Batch 2/3 Cost: 0.839995
# Epoch   29/50 Batch 3/3 Cost: 0.071582
# Epoch   30/50 Batch 1/3 Cost: 0.376930
# Epoch   30/50 Batch 2/3 Cost: 0.257346
# Epoch   30/50 Batch 3/3 Cost: 0.846116
# Epoch   31/50 Batch 1/3 Cost: 0.979208
# Epoch   31/50 Batch 2/3 Cost: 0.095896
# Epoch   31/50 Batch 3/3 Cost: 0.472551
# Epoch   32/50 Batch 1/3 Cost: 0.128878
# Epoch   32/50 Batch 2/3 Cost: 0.918702
# Epoch   32/50 Batch 3/3 Cost: 0.675469
# Epoch   33/50 Batch 1/3 Cost: 0.179609
# Epoch   33/50 Batch 2/3 Cost: 0.852987
# Epoch   33/50 Batch 3/3 Cost: 0.047087
# Epoch   34/50 Batch 1/3 Cost: 0.074099
# Epoch   34/50 Batch 2/3 Cost: 0.285151
# Epoch   34/50 Batch 3/3 Cost: 1.346423
# Epoch   35/50 Batch 1/3 Cost: 0.583906
# Epoch   35/50 Batch 2/3 Cost: 0.600245
# Epoch   35/50 Batch 3/3 Cost: 0.063127
# Epoch   36/50 Batch 1/3 Cost: 0.458178
# Epoch   36/50 Batch 2/3 Cost: 0.596617
# Epoch   36/50 Batch 3/3 Cost: 0.000032
# Epoch   37/50 Batch 1/3 Cost: 0.431327
# Epoch   37/50 Batch 2/3 Cost: 0.771052
# Epoch   37/50 Batch 3/3 Cost: 0.196771
# Epoch   38/50 Batch 1/3 Cost: 0.779043
# Epoch   38/50 Batch 2/3 Cost: 0.129341
# Epoch   38/50 Batch 3/3 Cost: 0.013198
# Epoch   39/50 Batch 1/3 Cost: 0.090049
# Epoch   39/50 Batch 2/3 Cost: 0.620910
# Epoch   39/50 Batch 3/3 Cost: 0.976911
# Epoch   40/50 Batch 1/3 Cost: 0.791228
# Epoch   40/50 Batch 2/3 Cost: 0.294776
# Epoch   40/50 Batch 3/3 Cost: 0.068521
# Epoch   41/50 Batch 1/3 Cost: 0.250531
# Epoch   41/50 Batch 2/3 Cost: 0.129513
# Epoch   41/50 Batch 3/3 Cost: 1.285201
# Epoch   42/50 Batch 1/3 Cost: 0.520691
# Epoch   42/50 Batch 2/3 Cost: 0.584295
# Epoch   42/50 Batch 3/3 Cost: 0.122611
# Epoch   43/50 Batch 1/3 Cost: 0.147505
# Epoch   43/50 Batch 2/3 Cost: 0.487523
# Epoch   43/50 Batch 3/3 Cost: 1.006143
# Epoch   44/50 Batch 1/3 Cost: 0.853274
# Epoch   44/50 Batch 2/3 Cost: 0.139035
# Epoch   44/50 Batch 3/3 Cost: 0.552837
# Epoch   45/50 Batch 1/3 Cost: 0.049590
# Epoch   45/50 Batch 2/3 Cost: 1.148386
# Epoch   45/50 Batch 3/3 Cost: 0.126336
# Epoch   46/50 Batch 1/3 Cost: 0.350174
# Epoch   46/50 Batch 2/3 Cost: 0.712601
# Epoch   46/50 Batch 3/3 Cost: 0.319987
# Epoch   47/50 Batch 1/3 Cost: 0.670372
# Epoch   47/50 Batch 2/3 Cost: 0.630887
# Epoch   47/50 Batch 3/3 Cost: 0.084070
# Epoch   48/50 Batch 1/3 Cost: 0.607415
# Epoch   48/50 Batch 2/3 Cost: 0.033609
# Epoch   48/50 Batch 3/3 Cost: 0.778361
# Epoch   49/50 Batch 1/3 Cost: 0.238559
# Epoch   49/50 Batch 2/3 Cost: 0.906692
# Epoch   49/50 Batch 3/3 Cost: 0.184972
# Epoch   50/50 Batch 1/3 Cost: 0.256434
# Epoch   50/50 Batch 2/3 Cost: 0.065138
# Epoch   50/50 Batch 3/3 Cost: 1.355503

# %%
# 임의의 입력 [73, 80, 75]를 선언
new_var =  torch.FloatTensor([[73, 80, 75]]) 
# 입력한 값 [73, 80, 75]에 대해서 예측값 y를 리턴받아서 pred_y에 저장
pred_y = model(new_var) 
print("훈련 후 입력이 73, 80, 75일 때의 예측값 :", pred_y)
# Out:
# 훈련 후 입력이 73, 80, 75일 때의 예측값 : tensor([[151.2399]], grad_fn=<AddmmBackward0>)
